# %%
from library import Classify
import pandas as pd

# %%
dataframe = pd.read_csv("ressources/clean_Presidentielles.csv")
dataframe
# Out:
#                      id                created_at  \
# 0   1587370173035692032  2022-11-01T09:05:15.000Z
# 1   1587369809443946496  2022-11-01T09:03:49.000Z
# 2   1587369628761735168  2022-11-01T09:03:06.000Z
# 3   1587369590388129792  2022-11-01T09:02:56.000Z
# 4   1587369245473738752  2022-11-01T09:01:34.000Z
# ..                  ...                       ...
# 95  1587223150999359489  2022-10-31T23:21:03.000Z
# 96  1587222464760799235  2022-10-31T23:18:19.000Z
# 97  1587222462072344581  2022-10-31T23:18:18.000Z
# 98  1587222176738017282  2022-10-31T23:17:10.000Z
# 99  1587221185187794948  2022-10-31T23:13:14.000Z
#
#                                                  text   edit_history_tweet_ids
# 0   @ Quand arriveront les prochaines élections pr...  ['1587370173035692032']
# 1   @ @ Cela fait des mois que les extrémistes du ...  ['1587369809443946496']
# 2   @ Aux 2 dernières présidentielles ,  l’extrême...  ['1587369628761735168']
# ...

# %%
dataframe2 = Classify.naive(dataframe)
dataframe2
# Out:
# @ Il faut savoir plus t'es incapable meilleurs est la place avec le poudré pinocchio .  Vous allez voir avant les prochaines élections présidentielles tous ses copains auront une place pour rien faire payer très cher avec nos impôts allez 0
# @ @ @ @ Non ,  il a eu tort :
# - historiquement ,  si dans quelques cas on peut dire que Vichy a été modérateur ,  dans la plupart des cas le régime a dépassé les attentes des allemands (ex Bousquet)
# - quel intérêt pour les présidentielles de 2022  ,
#
# Un suicide volontaire ou de la bêtise ,  ,  ,  intérêt 0
# @ La notion de calcul n'est pas la plus grande qualité à la NUPES , Je vais faire simple pour que tu comprennes  ,  Toi avoir perdue les présidentielles toi avoir perdue les législatives toi ne pas avoir la majorité au parlement  ,  Toi comprendre  ,  Pas gagné toi  ,  grande 0
# ...

# %%
dataframe2.to_csv('ressources/naif_Presidentielles.csv')
