# %%
from library import Cleaning
import pandas as pd

# %%
raw_data = pd.read_csv("ressources/Equipe_de_France.csv")
raw_data
# Out:
#     Unnamed: 0   edit_history_tweet_ids  \
# 0          NaN  ['1602050348860203010']
# 1          NaN  ['1602050336495210506']
# 2          NaN  ['1602050321525661696']
# 3          NaN  ['1602050212175937537']
# 4          NaN  ['1602050205800710144']
# 5          NaN  ['1602050117909229568']
# 6          NaN  ['1602050101878439937']
# 7          NaN  ['1602050042361167874']
# 8          NaN  ['1602049939953041410']
# 9          NaN  ['1602049901009186817']
# 10         NaN  ['1602049874333429761']
# 11         NaN  ['1602049726706245632']
# 12         NaN  ['1602049725645324288']
# 13         NaN  ['1602049643105615872']
# 14         NaN  ['1602049628853207041']
# 15         NaN  ['1602049570753871873']
# 16         NaN  ['1602049423332212739']
# 17         NaN  ['1602049315899310080']
# 18         NaN  ['1602049177688711168']
# 19         NaN  ['1602049127063379969']
# 20         NaN  ['1602049055856955392']
# 21         NaN  ['1602048949678141440']
# ...

# %%
df_test = Cleaning.cleaning_chain(raw_data,Cleaning.CLEANING_FUNCTIONS)
df_test
# Out:
#     Unnamed: 0   edit_history_tweet_ids  \
# 0          NaN  ['1602050348860203010']
# 1          NaN  ['1602050336495210506']
# 2          NaN  ['1602050321525661696']
# 3          NaN  ['1602050212175937537']
# 4          NaN  ['1602050205800710144']
# 5          NaN  ['1602050117909229568']
# 6          NaN  ['1602050101878439937']
# 7          NaN  ['1602050042361167874']
# 8          NaN  ['1602049939953041410']
# 9          NaN  ['1602049901009186817']
# 10         NaN  ['1602049874333429761']
# 11         NaN  ['1602049726706245632']
# 12         NaN  ['1602049725645324288']
# 13         NaN  ['1602049643105615872']
# 14         NaN  ['1602049628853207041']
# 15         NaN  ['1602049570753871873']
# 16         NaN  ['1602049423332212739']
# 17         NaN  ['1602049315899310080']
# 18         NaN  ['1602049177688711168']
# 19         NaN  ['1602049127063379969']
# 20         NaN  ['1602049055856955392']
# 21         NaN  ['1602048949678141440']
# ...

# %%
df_test.to_csv("ressources/clean_Equipe_de_France.csv",index = False)
